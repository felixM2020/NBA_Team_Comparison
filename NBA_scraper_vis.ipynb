# %% [markdown]
# <a href="https://colab.research.google.com/github/felixM2020/NBA_Team_Comparison/blob/main/NBA_scraper_vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NBA Team Data Visualisation

# %% [markdown]
# ##Scrape data

# %% [markdown]
# ###Import Scraping Tools

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ###Create Soup

# %%
link = 'https://www.espn.com/nba/stats/team/_/season/2022/seasontype/2/table/offensive/sort/avgPoints/dir/desc'
r = requests.get(link)
soup = BeautifulSoup(r.content, 'html.parser')

# %% [markdown]
# ###Scrape table rows

# %%
def find_teams(table):
  table_container = soup.find('table', {'class': 'Table Table--align-right Table--fixed Table--fixed-left'})

  teams_container = table_container.find('tbody', {'class':'Table__TBODY'})
  teams = teams_container.find_all('div', {'class':'flex items-start mr7'})
  return [x.text for x in teams]

def row_to_array(row_values):
  return [x.text for x in row_values]

def find_values(table):
  values_container = soup.find('div', {'class':'Table__Scroller'})
  values = values_container.find_all('tr', {'class': 'Table__TR Table__TR--sm Table__even'})
  return [row_to_array(x.find_all('td', {'class':'Table__TD'})) for x in values]




table = soup.find('div', {'class': 'ResponsiveTable ResponsiveTable--fixed-left mt4 Table2__title--remove-capitalization'})
teams = find_teams(table)
values = find_values(table)
rows = []
for i in range(30):
  team = teams[i]
  stats = values[i]
  stats.insert(0,team)
  rows.append(stats)

for row in rows:
  print(row)
# Out:
# ['Minnesota Timberwolves', '82', '115.9', '41.6', '91.0', '45.7', '14.8', '41.3', '35.8', '18.0', '23.1', '77.8', '11.2', '32.9', '44.2', '25.7', '8.8', '5.6', '13.7', '21.8']
# ['Memphis Grizzlies', '82', '115.6', '43.5', '94.4', '46.1', '11.5', '32.7', '35.3', '17.0', '23.1', '73.4', '14.1', '35.0', '49.2', '26.0', '9.8', '6.5', '12.5', '19.8']
# ['Milwaukee Bucks', '82', '115.5', '41.8', '89.4', '46.8', '14.1', '38.4', '36.6', '17.8', '22.9', '77.6', '10.3', '36.5', '46.7', '23.9', '7.6', '4.0', '12.7', '18.2']
# ['Charlotte Hornets', '82', '115.3', '42.8', '91.4', '46.8', '13.9', '38.2', '36.5', '15.8', '21.4', '74.0', '10.8', '33.7', '44.6', '28.1', '8.6', '4.9', '12.7', '19.9']
# ['Phoenix Suns', '82', '114.8', '43.7', '90.1', '48.5', '11.6', '31.9', '36.4', '15.9', '19.9', '79.7', '9.8', '35.5', '45.3', '27.4', '8.6', '4.4', '12.3', '19.9']
# ['Atlanta Hawks', '82', '113.9', '41.5', '88.3', '47.0', '12.9', '34.4', '37.4', '18.1', '22.3', '81.2', '10.0', '33.9', '44.0', '24.6', '7.2', '4.2', '11.3', '18.7']
# ['Utah Jazz', '82', '113.6', '40.6', '86.2', '47.1', '14.5', '40.3', '36.0', '17.9', '23.4', '76.7', '10.8', '35.6', '46.3', '22.4', '7.2', '4.9', '13.2', '18.9']
# ['San Antonio Spurs', '82', '113.2', '43.2', '92.7', '46.7', '11.3', '32.0', '35.2', '15.4', '20.4', '75.4', '11.0', '34.3', '45.3', '27.9', '7.6', '4.9', '12.3', '18.1']
# ['Brooklyn Nets', '82', '112.9', '42.0', '88.4', '47.5', '11.5', '31.7', '36.1', '17.5', '21.7', '80.5', '10.3', '34.1', '44.4', '25.3', '7.1', '5.5', '13.2', '20.4']
# ['Denver Nuggets', '82', '112.7', '41.7', '86.3', '48.3', '12.7', '35.9', '35.3', '16.7', '21.0', '79.5', '9.2', '34.9', '44.1', '27.8', '7.2', '3.7', '13.8', '20.0']
# ['Los Angeles Lakers', '82', '112.1', '41.6', '88.8', '46.9', '12.0', '34.5', '34.7', '16.8', '23.0', '73.2', '9.5', '34.5', '44.0', '24.0', '7.6', '5.2', '13.9', '20.2']
# ['Boston Celtics', '82', '111.8', '40.7', '87.4', '46.6', '13.2', '37.1', '35.6', '17.0', '20.9', '81.6', '10.5', '35.5', '46.1', '24.8', '7.2', '5.8', '13.0', '18.5']
# ['Chicago Bulls', '82', '111.6', '41.7', '86.9', '48.0', '10.6', '28.8', '36.9', '17.5', '21.5', '81.3', '8.7', '33.7', '42.3', '23.9', '7.1', '4.1', '12.1', '18.8']
# ['Indiana Pacers', '82', '111.5', '41.4', '89.5', '46.3', '12.2', '35.4', '34.4', '16.4', '21.4', '76.8', '11.3', '32.6', '43.9', '25.4', '7.1', '5.6', '13.6', '20.4']
# ['Golden State Warriors', '82', '111.0', '40.5', '86.4', '46.9', '14.3', '39.4', '36.4', '15.6', '20.3', '76.9', '9.8', '35.7', '45.5', '27.1', '8.8', '4.5', '14.3', '21.0']
# ['Sacramento Kings', '82', '110.3', '40.5', '88.1', '46.0', '11.4', '33.2', '34.4', '17.9', '23.3', '76.8', '9.6', '33.4', '42.9', '23.7', '7.2', '4.5', '13.5', '18.9']
# ['Miami Heat', '82', '110.0', '39.6', '84.8', '46.7', '13.6', '35.8', '37.9', '17.3', '21.4', '80.8', '9.8', '33.9', '43.7', '25.5', '7.4', '3.2', '13.8', '20.5']
# ['Philadelphia 76ers', '82', '109.9', '39.4', '84.5', '46.6', '11.6', '31.8', '36.4', '19.6', '23.8', '82.1', '8.5', '33.8', '42.3', '23.7', '7.7', '5.3', '11.7', '19.4']
# ['Houston Rockets', '82', '109.7', '39.4', '86.4', '45.6', '13.5', '38.7', '34.9', '17.5', '24.5', '71.3', '9.6', '32.4', '42.0', '23.6', '7.3', '4.7', '15.7', '20.6']
# ['Toronto Raptors', '82', '109.4', '40.6', '91.3', '44.5', '11.9', '34.2', '34.9', '16.2', '21.3', '75.9', '13.4', '32.0', '45.3', '22.1', '9.0', '4.6', '11.6', '19.6']
# ['New Orleans Pelicans', '82', '109.3', '40.2', '88.0', '45.7', '10.6', '32.1', '33.2', '18.3', '23.2', '78.9', '12.0', '33.2', '45.2', '25.0', '8.3', '4.0', '13.3', '19.7']
# ['Washington Wizards', '82', '108.6', '40.6', '86.0', '47.2', '10.5', '30.6', '34.2', '17.0', '21.7', '78.3', '9.0', '34.1', '43.1', '25.0', '6.4', '5.0', '12.6', '18.8']
# ['LA Clippers', '82', '108.4', '40.1', '87.4', '45.8', '12.8', '34.2', '37.4', '15.5', '19.6', '79.3', '9.1', '34.9', '44.0', '24.0', '7.4', '5.0', '13.0', '18.6']
# ['Dallas Mavericks', '82', '108.0', '39.3', '85.1', '46.1', '13.1', '37.4', '35.0', '16.4', '21.2', '77.1', '9.3', '33.8', '43.0', '23.4', '6.7', '4.0', '11.7', '19.7']
# ['Cleveland Cavaliers', '82', '107.8', '39.7', '84.6', '46.9', '11.6', '32.8', '35.5', '16.8', '22.1', '76.0', '10.2', '34.0', '44.2', '25.2', '7.1', '4.2', '13.3', '17.5']
# ['New York Knicks', '82', '106.5', '37.7', '86.2', '43.7', '13.2', '36.9', '35.7', '18.0', '24.1', '74.4', '11.5', '34.6', '46.1', '21.9', '7.0', '4.9', '12.4', '20.4']
# ['Portland Trail Blazers', '82', '106.2', '38.5', '87.1', '44.2', '12.7', '36.8', '34.6', '16.4', '21.6', '76.0', '10.4', '32.5', '42.9', '22.9', '8.0', '4.5', '13.7', '21.1']
# ['Detroit Pistons', '82', '104.8', '38.2', '88.6', '43.1', '11.3', '34.6', '32.6', '17.2', '22.0', '78.2', '11.0', '32.0', '43.0', '23.5', '7.7', '4.8', '13.4', '21.9']
# ['Orlando Magic', '82', '104.2', '38.3', '88.3', '43.4', '12.2', '36.9', '33.1', '15.5', '19.7', '78.7', '9.1', '35.2', '44.3', '23.7', '6.8', '4.5', '13.8', '19.7']
# ['Oklahoma City Thunder', '82', '103.7', '38.3', '89.1', '43.0', '12.1', '37.4', '32.3', '15.0', '19.9', '75.6', '10.4', '35.2', '45.6', '22.2', '7.6', '4.6', '13.3', '18.3']

# %% [markdown]
# ### Scrape headers

# %%
def find_headers(table):
  values_container = soup.find('div', {'class':'Table__Scroller'})
  headers = values_container.find_all('th', {'class': 'Table__TH'})
  return [x.text for x in headers]

cols = ['Team']
headers = find_headers(table)
[cols.append(x) for x in headers]
cols
# Out:
# ['Team',
#  'GP',
#  'PTS',
#  'FGM',
#  'FGA',
#  'FG%',
#  '3PM',
#  '3PA',
#  '3P%',
#  'FTM',
#  'FTA',
#  'FT%',
#  'OR',
#  'DR',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'TO',
#  'PF']

# %% [markdown]
# ###Combine headers and rows into a df

# %%
df = pd.DataFrame(rows, columns = cols)
df = df.set_index('Team')
for i in range(0, len(df.columns)):
  col = df.columns[i]
  df[col] = df[col].apply(lambda x : float(x))
print(df.dtypes)
# Out:
# GP     float64
# PTS    float64
# FGM    float64
# FGA    float64
# FG%    float64
# 3PM    float64
# 3PA    float64
# 3P%    float64
# FTM    float64
# FTA    float64
# FT%    float64
# OR     float64
# DR     float64
# REB    float64
# AST    float64
# STL    float64
# BLK    float64
# TO     float64
# PF     float64
# dtype: object

# %% [markdown]
# ##Prepare Data for Visualisation

# %%
from scipy import stats

norm = df
for col in df.columns:
  norm[col] = pd.Series(stats.zscore(norm[col]))
norm = norm.drop('GP', axis = 1)

# %% [markdown]
# #Visualise Data

# %% [markdown]
# ### All Teams

# %%
import plotly.graph_objects as go
fig = go.Figure()
team = [0,0]
cols = norm.columns
teams = norm.index
for i in range(len(norm.index)):
  X = norm.iloc[i,:].values.flatten().tolist()
  fig.add_trace(go.Scatterpolar(
        r=X,
        theta=cols,
        fill='toself',
        name = norm.index[i]
      ))

                  
fig.update_layout(
      polar=dict(
          radialaxis=dict(
            visible=True,
            range=[-4, 4]
              )),

        showlegend=True,
        title = 'NBA League Wide Team Comparison'
      )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="54b0fd2e-6ae7-4de1-835e-af610e4fd768" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54b0fd2e-6ae7-4de1-835e-af610e4fd768")) {                    Plotly.newPlot(                        "54b0fd2e-6ae7-4de1-835e-af610e4fd768",                        [{"fill":"toself","name":"Minnesota Timberwolves","r":[1.5597016952139342,0.6183017184716122,1.2255954604024075,-0.2948700024382033,2.0062534727007546,2.0361274990840434,0.32415795928638286,1.0291570595426436,0.9351308338915996,0.1119278323012356,0.6890518365481016,-1.0601661944936156,-0.16425698858544252,0.6091281259207952,1.521871452853257,1.311438030118233,0.7198103140533095,2.0136230753540088],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Memphis Grizzlies","r":[1.4713055034196907,1.8211412390477855,2.657562664996276,-0.01625267729974361,-0.799100959465556,-0.8250974179294777,-0.04143372411931647,0.06432231622141822,0.9351308338915996,-1.5296803747834877,3.0125987272335624,0.774736834437636,3.120882783123408,0.7842767883261368,2.8300704094606397,2.652681470011881,-0.6022902627792972,0.14627555570578082],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Milwaukee Bucks","r":[1.4418401061549455,0.7449164048480489,0.5517285405935319,0.4713276416925597,1.4111782901200212,1.0712958410213442,0.9091046527355049,0.8361901108783991,0.7847076434532698,0.03730927743374697,-0.0320489226301436,2.0853818551028147,1.4783128972689825,-0.44176384851125194,-0.04796729507560339,-1.0729947519149174,-0.3819401666405301,-1.347602460012803],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Charlotte Hornets","r":[1.3829093116254512,1.3779898367302457,1.3940621903546295,0.4713276416925597,1.2411568093826697,1.004755726672194,0.8359863160543639,-1.0934793757640515,-0.34346628483418684,-1.3058247101810272,0.3685626102466599,-0.36115551680551655,0.09855419315126457,2.0103174251635254,1.2602316615317792,0.26824868797873036,-0.3819401666405301,0.23964293168819023],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Phoenix Suns","r":[1.2355823253017173,1.9477559254242265,0.8465453180099113,1.6554512735310196,-0.7140902190968802,-1.0912578753260858,0.762867979373223,-0.9969959014319293,-1.4716402131216435,0.8208041035423697,-0.43266045550694715,1.2116185079926955,0.5584737611905007,1.6016372128843945,1.2602316615317792,-0.4768865564066293,-0.8226403589180644,0.23964293168819023],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Atlanta Hawks","r":[0.9703937499189988,0.5549943752833917,0.08844503322492459,0.610636304261792,0.39104940569590907,-0.25950644596168965,1.4940513461846217,1.1256405338747675,0.3334380721382888,1.3804432650485265,-0.2724158423562263,-0.1864028473834964,-0.29566257945379837,-0.033083636232121016,-0.5712468777185558,-0.7749406541607734,-1.924390839611904,-0.8807655801007459],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Utah Jazz","r":[0.8819975581247552,-0.014771713410584654,-0.7960052990242256,0.6802906355464082,1.7512212515947256,1.703426927338285,0.47039463264866466,0.9326735852105196,1.1607656195490887,-0.29847421946994396,0. ...

# %% [markdown]
# Store individual plots in dictionary

# %%
import plotly.graph_objects as go
team_traces = {}
teams = norm.index
cols = norm.columns
for i in range(len(norm.index)):
  X = norm.iloc[i,:].values.flatten().tolist()
  name = teams[i]
  team_traces[name] = {
      'r':X,
      'theta':cols,
      'name' : teams[i]}

def to_polar(dic_entry):
  return go.Scatterpolar(
        r=dic_entry['r'],
        theta=dic_entry['theta'],
        fill='toself',
        name = dic_entry['name']
      )

# %% [markdown]
# Create Figure and buttons

# %%
from numpy import true_divide
fig = go.Figure()
for i in range(len(norm.index)):
  X = norm.iloc[i,:].values.flatten().tolist()
  fig.add_trace(go.Scatterpolar(
        r=X,
        theta=cols,
        fill='toself',
        name = norm.index[i]
      ))

def visible(i,but):
  team[but] = i
  out = []
  for b in range(30):
    if b == team[0] or b == team[1]:
      out.append(True)
    else:
      out.append(False)
  return out

buttons = list()
for i in range(len(teams)):
  current = team_traces[teams[i]]
  x = current['r']
  visible = [False for c in range(30)]
  visible[i] = True
  button = dict(label = teams[i],
                       method="update",
                       args=[{'visible': visible, 'name': current['name'],'type' : 'scatterpolar', 'fill':'toself'},
                             [i]
                        ]  
                  )
  buttons.append(button)

# %% [markdown]
# Add buttons and labels

# %%
updatemenu = []
first_menu = dict(x = 0.1, y = 0.1,
            active=0,
            buttons= buttons, showactive = True
             )
updatemenu.append(first_menu)

fig.update_layout(
    updatemenus=updatemenu,
        annotations = [
                       dict(text="Team 2", x=0.1, xref="paper", y=0.1, yref="paper",
                             align="left", showarrow=False),
                       dict(text="Team 1", x=0.1, xref="paper", y=0.53, yref="paper",
                             align="left", showarrow=False), 
                       ]
            ,

    


      polar=dict(
          radialaxis=dict(
            visible=True,
            range=[-4, 4]
              )),

        showlegend=False,
      title = 'Team Comparisons'
      )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1f49dc9b-a43e-4aa7-a0c8-d8697b23267d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f49dc9b-a43e-4aa7-a0c8-d8697b23267d")) {                    Plotly.newPlot(                        "1f49dc9b-a43e-4aa7-a0c8-d8697b23267d",                        [{"fill":"toself","name":"Minnesota Timberwolves","r":[1.5597016952139342,0.6183017184716122,1.2255954604024075,-0.2948700024382033,2.0062534727007546,2.0361274990840434,0.32415795928638286,1.0291570595426436,0.9351308338915996,0.1119278323012356,0.6890518365481016,-1.0601661944936156,-0.16425698858544252,0.6091281259207952,1.521871452853257,1.311438030118233,0.7198103140533095,2.0136230753540088],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Memphis Grizzlies","r":[1.4713055034196907,1.8211412390477855,2.657562664996276,-0.01625267729974361,-0.799100959465556,-0.8250974179294777,-0.04143372411931647,0.06432231622141822,0.9351308338915996,-1.5296803747834877,3.0125987272335624,0.774736834437636,3.120882783123408,0.7842767883261368,2.8300704094606397,2.652681470011881,-0.6022902627792972,0.14627555570578082],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Milwaukee Bucks","r":[1.4418401061549455,0.7449164048480489,0.5517285405935319,0.4713276416925597,1.4111782901200212,1.0712958410213442,0.9091046527355049,0.8361901108783991,0.7847076434532698,0.03730927743374697,-0.0320489226301436,2.0853818551028147,1.4783128972689825,-0.44176384851125194,-0.04796729507560339,-1.0729947519149174,-0.3819401666405301,-1.347602460012803],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Charlotte Hornets","r":[1.3829093116254512,1.3779898367302457,1.3940621903546295,0.4713276416925597,1.2411568093826697,1.004755726672194,0.8359863160543639,-1.0934793757640515,-0.34346628483418684,-1.3058247101810272,0.3685626102466599,-0.36115551680551655,0.09855419315126457,2.0103174251635254,1.2602316615317792,0.26824868797873036,-0.3819401666405301,0.23964293168819023],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Phoenix Suns","r":[1.2355823253017173,1.9477559254242265,0.8465453180099113,1.6554512735310196,-0.7140902190968802,-1.0912578753260858,0.762867979373223,-0.9969959014319293,-1.4716402131216435,0.8208041035423697,-0.43266045550694715,1.2116185079926955,0.5584737611905007,1.6016372128843945,1.2602316615317792,-0.4768865564066293,-0.8226403589180644,0.23964293168819023],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Atlanta Hawks","r":[0.9703937499189988,0.5549943752833917,0.08844503322492459,0.610636304261792,0.39104940569590907,-0.25950644596168965,1.4940513461846217,1.1256405338747675,0.3334380721382888,1.3804432650485265,-0.2724158423562263,-0.1864028473834964,-0.29566257945379837,-0.033083636232121016,-0.5712468777185558,-0.7749406541607734,-1.924390839611904,-0.8807655801007459],"theta":["PTS","FGM","FGA","FG%","3PM","3PA","3P%","FTM","FTA","FT%","OR","DR","REB","AST","STL","BLK","TO","PF"],"type":"scatterpolar"},{"fill":"toself","name":"Utah Jazz","r":[0.8819975581247552,-0.014771713410584654,-0.7960052990242256,0.6802906355464082,1.7512212515947256,1.703426927338285,0.47039463264866466,0.9326735852105196,1.1607656195490887,-0.29847421946994396,0. ...
